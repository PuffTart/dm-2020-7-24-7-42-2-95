# %% [markdown]
# # 决策树建模例子

# %% [markdown]
# 简单创建一个数据集,两个特征,一个目标变量,共两行数据

# %% [markdown]
# # 1 导入相关库

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # 2 加载数据集

# %%
iris = datasets.load_iris()  # iris为sklearn.utils.Bunch,类似字典{'data':array,'target':array，'target_names':array,'feature_names':list}
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df
# 拆分训练集和测试集
# X_train, X_test, Y_train, Y_test = train_test_split(df[data.feature_names], df['target'], random_state=0)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# # 3 构建模型及预测

# %%
# 1 做一个模型例子
clf = DecisionTreeClassifier(max_depth = 3, 
                             random_state = 0)  # 设置随机种子
# 2 训练模型
clf.fit(df[iris.feature_names], df['target'])

# 3 预测测试测试集
clf.predict([[6,1,3,1]])
# Out:
# array([1])

# %% [markdown]
# # 4 画图

# %%
fig = plt.figure(figsize = (12,3),dpi=300)   # 12是宽，3是高，dpi(dop per inch) 每英寸的像素点数 ,设置像素
tree.plot_tree(clf,
               feature_names = iris.feature_names, 
               class_names=iris.target_names,
               filled = True);  # 填充颜色
# fig.savefig('imagename.png')
